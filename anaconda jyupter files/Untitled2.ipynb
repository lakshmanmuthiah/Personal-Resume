# %%
STT='https://worldpopulationreview.com/countries/countries-by-gdp/#worldCountries.html'

# %%
import requests

# %%
r=requests.get(STT)

# %%
r
# Out:
# <Response [200]>

# %%
r
# Out:
# <Response [200]>

# %%
type(r.content)
# Out:
# bytes

# %%
s=r.text

# %%
s
# Out:
# '<!DOCTYPE html><html><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1"/><title>GDP Ranked by Country 2020</title><link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/css/bootstrap.min.css" integrity="sha384-ggOyR0iXCbMQv3Xipma34MD+dH/1fQ784/j6cY/iJTQUOhcWr7x9JvoRxT2MZw1T" crossorigin="anonymous"/><script data-cfasync="false" type="text/javascript">(function (a, c, s, u){\'Insticator\'in a || (a.Insticator={ad:{loadAd: function (b){Insticator.ad.q.push(b)}, q: []}, helper:{}, embed:{}, version: "4.0", q: [], load: function (t, o){Insticator.q.push({t: t, o: o})}}); var b=c.createElement(s); b.src=u; b.async=!0; var d=c.getElementsByTagName(s)[0]; d.parentNode.insertBefore(b, d)})(window, document, \'script\', \'//d3lcz8vpax4lo2.cloudfront.net/ads-code/777dd340-6dea-49f5-af7f-43d2f0d34107.js\')</script><script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script><script type="text/jav
# ...

# %%
s
# Out:
# '<!DOCTYPE html>\n<!--[if (gt IE 9)|!(IE)]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->\n  <head>\n    <meta charset="utf-8">\n    <!-- www.phpied.com/conditional-comments-block-downloads/ -->\n    <!-- Always force latest IE rendering engine\n         (even in intranet) & Chrome Frame\n         Remove this if you use the .htaccess -->\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <!--  Mobile Viewport Fix\n          j.mp/mobileviewport & davidbcalhoun.com/2010/viewport-metatag\n          device-width: Occupy full width of the screen in its current orientation\n          initial-scale = 1.0 retains dimensions instead of zooming out if page height > device height\n          user-scalable = yes allows the user to zoom in -->\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <title>simple</title>\n    <!-- http://dev.w3.org/html5/markup/meta.name.html -->\n    <meta name="application-name" content="simple">\n    <!-- Speaking 
# ...

# %%
type(s)
# Out:
# str

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(s,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if (gt IE 9)|!(IE)]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <!-- www.phpied.com/conditional-comments-block-downloads/ -->
# <!-- Always force latest IE rendering engine
#          (even in intranet) & Chrome Frame
#          Remove this if you use the .htaccess -->
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <!--  Mobile Viewport Fix
#           j.mp/mobileviewport & davidbcalhoun.com/2010/viewport-metatag
#           device-width: Occupy full width of the screen in its current orientation
#           initial-scale = 1.0 retains dimensions instead of zooming out if page height > device height
#           user-scalable = yes allows the user to zoom in -->
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>simple</title>
# <!-- http://dev.w3.org/html5/markup/meta.name.html -->
# <meta content="simple" name="application-name"/>
# ...

# %%
div
# Out:
# [<div class="container-fluid main-container">
#  <h1>ALL GOLD DETAILS</h1>
#  <h3>Note:-</h3>
#  <p><b>Click on the 1st Column Entries to Edit/Update/Release Gold S.No</b></p>
#  <table class="table">
#  <tr>
#  <td><a href="/simple/jewellerygolds/releasegold/1715" target="_blank">5709</a></td>
#  <td>2020-03-02</td>
#  <td>12000</td>
#  <td>BALRAJ</td>
#  <td>IYYAVU</td>
#  <td>SUBRAMANIYA NAGAR, 3RD STREET</td>
#  <td>1</td>
#  <td>DOLLAR CHAIN 1</td>
#  <td>7</td>
#  <td>0</td>
#  <td>0001-01-01</td>
#  <td>LIVE</td>
#  </tr>
#  </table></div>]

# %%
import json

# %%
print(soup.find_all('td',class_='tables'))
# Out:
# []

# %%
table = soup.find("table", { "class" : "datatableStyles__StyledTable-bwtkle-1 hOnuWY table table-striped" })

# %%
trs = table.find_all('tr')

# %%
t=(trs[0].text)

# %%
for td in trs[0].find_all('th'):
    td.get_text(strip=True)
    print(td)
# Out:
# <th><span class="datatableStyles__StyledTableHeader-bwtkle-2 gxxLKm"><a data-field="rank" style="color:black;cursor:pointer;display:inline-block">Rank<!-- --> <svg fill="currentColor" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 320 512" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M288.662 352H31.338c-17.818 0-26.741-21.543-14.142-34.142l128.662-128.662c7.81-7.81 20.474-7.81 28.284 0l128.662 128.662c12.6 12.599 3.676 34.142-14.142 34.142z"></path></svg> </a></span></th>
# <th><span class="datatableStyles__StyledTableHeader-bwtkle-2 gxxLKm"><a data-field="country" style="color:black;cursor:pointer;display:inline-block">Name<!-- --> <!-- --> </a></span></th>
# <th><span class="datatableStyles__StyledTableHeader-bwtkle-2 gxxLKm"><a data-field="imfGDP" style="color:black;cursor:pointer;display:inline-block">GDP (IMF '19)<!-- --> <!-- --> </a></span></th>
# ...

# %% [markdown]
# # trs[0]

# %%
s=t.strip(" ")

# %%
ts=list(s.split(" "))

# %%
s
# Out:
# "Rank  Name  GDP (IMF '19)  GDP (UN '16)  GDP Per Capita  2019 Population"

# %%
trs[0]
# Out:
# <tr><th><span class="datatableStyles__StyledTableHeader-bwtkle-2 gxxLKm"><a data-field="rank" style="color:black;cursor:pointer;display:inline-block">Rank<!-- --> <svg fill="currentColor" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 320 512" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M288.662 352H31.338c-17.818 0-26.741-21.543-14.142-34.142l128.662-128.662c7.81-7.81 20.474-7.81 28.284 0l128.662 128.662c12.6 12.599 3.676 34.142-14.142 34.142z"></path></svg> </a></span></th><th><span class="datatableStyles__StyledTableHeader-bwtkle-2 gxxLKm"><a data-field="country" style="color:black;cursor:pointer;display:inline-block">Name<!-- --> <!-- --> </a></span></th><th><span class="datatableStyles__StyledTableHeader-bwtkle-2 gxxLKm"><a data-field="imfGDP" style="color:black;cursor:pointer;display:inline-block">GDP (IMF '19)<!-- --> <!-- --> </a></span></th><th><span class="datatableStyles__StyledTableHeader-bwtkle-2 gxxLKm"><a data-field="unGDP" style="color:bl
# ...

# %%
trs[3]
# Out:
# <tr><td>209</td><td><a href="/countries/japan-population/">Japan</a></td><td>5.50 Tn</td><td>4.94 Tn</td><td>$43,450</td><td>126,476,461</td></tr>

# %%
duse

# %%
d.text
# Out:
# '\n\n5709\n2020-03-02\n12000\nBALRAJ\nIYYAVU\nSUBRAMANIYA NAGAR, 3RD STREET\n1\nDOLLAR CHAIN 1\n7\n0\n0001-01-01\nLIVE\n\n'

# %%
div

# %%
div
# Out:
# []

# %%
div.prettify()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-897c492fad2d> in <module>
# ----> 1 div.prettify()
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1576     def __getattr__(self, key):
#    1577         raise AttributeError(
# -> 1578             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1579         )
#
# AttributeError: ResultSet object has no attribute 'prettify'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
print(div)
# Out:
# [<div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation"><input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"><div class="toctitle" dir="ltr" lang="en"><h2 id="mw-toc-heading">Contents</h2><span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span></div>
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#Summary_of_classifications"><span class="tocnumber">1</span> <span class="toctext">Summary of classifications</span></a></li>
# <li class="toclevel-1 tocsection-2"><a href="#Market_segments"><span class="tocnumber">2</span> <span class="toctext">Market segments</span></a>
# <ul>
# <li class="toclevel-2 tocsection-3"><a href="#Microcar_/_kei_car"><span class="tocnumber">2.1</span> <span class="toctext">Microcar / kei car</span></a></li>
# ...

# %%
div.find_all('span')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-aef7de242b43> in <module>
# ----> 1 div.find_all('span')
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1576     def __getattr__(self, key):
#    1577         raise AttributeError(
# -> 1578             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1579         )
#
# AttributeError: ResultSet object has no attribute 'find_all'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
div
# Out:
# [<div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation"><input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"><div class="toctitle" dir="ltr" lang="en"><h2 id="mw-toc-heading">Contents</h2><span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span></div>
#  <ul>
#  <li class="toclevel-1 tocsection-1"><a href="#Summary_of_classifications"><span class="tocnumber">1</span> <span class="toctext">Summary of classifications</span></a></li>
#  <li class="toclevel-1 tocsection-2"><a href="#Market_segments"><span class="tocnumber">2</span> <span class="toctext">Market segments</span></a>
#  <ul>
#  <li class="toclevel-2 tocsection-3"><a href="#Microcar_/_kei_car"><span class="tocnumber">2.1</span> <span class="toctext">Microcar / kei car</span></a></li>
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-aef7de242b43> in <module>
# ----> 1 div.find_all('span')
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1576     def __getattr__(self, key):
#    1577         raise AttributeError(
# -> 1578             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1579         )
#
# AttributeError: ResultSet object has no attribute 'find_all'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
print(div.prettify())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-108-f233d74629db> in <module>
# ----> 1 print(div.prettify())
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1576     def __getattr__(self, key):
#    1577         raise AttributeError(
# -> 1578             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1579         )
#
# AttributeError: ResultSet object has no attribute 'prettify'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
div.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-c5826efdba7e> in <module>
# ----> 1 div.text
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1576     def __getattr__(self, key):
#    1577         raise AttributeError(
# -> 1578             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1579         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
div
# Out:
# [<div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation"><input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"><div class="toctitle" dir="ltr" lang="en"><h2 id="mw-toc-heading">Contents</h2><span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span></div>
#  <ul>
#  <li class="toclevel-1 tocsection-1"><a href="#Summary_of_classifications"><span class="tocnumber">1</span> <span class="toctext">Summary of classifications</span></a></li>
#  <li class="toclevel-1 tocsection-2"><a href="#Market_segments"><span class="tocnumber">2</span> <span class="toctext">Market segments</span></a>
#  <ul>
#  <li class="toclevel-2 tocsection-3"><a href="#Microcar_/_kei_car"><span class="tocnumber">2.1</span> <span class="toctext">Microcar / kei car</span></a></li>
# ...

# %%
div.find_all('a')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-033152caa23e> in <module>
# ----> 1 div.find_all('a')
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1576     def __getattr__(self, key):
#    1577         raise AttributeError(
# -> 1578             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1579         )
#
# AttributeError: ResultSet object has no attribute 'find_all'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
dive=soup.find_all('div',class_='toc')

# %%
dive
# Out:
# [<div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation"><input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"><div class="toctitle" dir="ltr" lang="en"><h2 id="mw-toc-heading">Contents</h2><span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span></div>
#  <ul>
#  <li class="toclevel-1 tocsection-1"><a href="#Summary_of_classifications"><span class="tocnumber">1</span> <span class="toctext">Summary of classifications</span></a></li>
#  <li class="toclevel-1 tocsection-2"><a href="#Market_segments"><span class="tocnumber">2</span> <span class="toctext">Market segments</span></a>
#  <ul>
#  <li class="toclevel-2 tocsection-3"><a href="#Microcar_/_kei_car"><span class="tocnumber">2.1</span> <span class="toctext">Microcar / kei car</span></a></li>
# ...

# %%
dive.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-103-fa86983c2f90> in <module>
# ----> 1 dive.text
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1576     def __getattr__(self, key):
#    1577         raise AttributeError(
# -> 1578             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1579         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
len(t)
# Out:
# 1

# %%
div
# Out:
# <div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation"><input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"><div class="toctitle" dir="ltr" lang="en"><h2 id="mw-toc-heading">Contents</h2><span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span></div>
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#Summary_of_classifications"><span class="tocnumber">1</span> <span class="toctext">Summary of classifications</span></a></li>
# <li class="toclevel-1 tocsection-2"><a href="#Market_segments"><span class="tocnumber">2</span> <span class="toctext">Market segments</span></a>
# <ul>
# <li class="toclevel-2 tocsection-3"><a href="#Microcar_/_kei_car"><span class="tocnumber">2.1</span> <span class="toctext">Microcar / kei car</span></a></li>
# ...

# %%
print(div.prettify())
# Out:
# <div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation">
#  <input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox">
#   <div class="toctitle" dir="ltr" lang="en">
#    <h2 id="mw-toc-heading">
#     Contents
#    </h2>
#    <span class="toctogglespan">
#     <label class="toctogglelabel" for="toctogglecheckbox">
#     </label>
#    </span>
#   </div>
#   <ul>
#    <li class="toclevel-1 tocsection-1">
#     <a href="#Summary_of_classifications">
#      <span class="tocnumber">
#       1
#      </span>
#      <span class="toctext">
#       Summary of classifications
#      </span>
#     </a>
#    </li>
#    <li class="toclevel-1 tocsection-2">
#     <a href="#Market_segments">
#      <span class="tocnumber">
#       2
#      </span>
#      <span class="toctext">
#       Market segments
#      </span>
#     </a>
#     <ul>
#      <li class="toclevel-2 tocsection-3">
#       <a href="#Microcar_/_kei_car">
# ...

# %%
soup.html
# Out:
# <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <!-- www.phpied.com/conditional-comments-block-downloads/ -->
# <!-- Always force latest IE rendering engine
#          (even in intranet) & Chrome Frame
#          Remove this if you use the .htaccess -->
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <!--  Mobile Viewport Fix
#           j.mp/mobileviewport & davidbcalhoun.com/2010/viewport-metatag
#           device-width: Occupy full width of the screen in its current orientation
#           initial-scale = 1.0 retains dimensions instead of zooming out if page height > device height
#           user-scalable = yes allows the user to zoom in -->
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>simple</title>
# <!-- http://dev.w3.org/html5/markup/meta.name.html -->
# <meta content="simple" name="application-name"/>
# <!-- Speaking of Google, don't forget to set your site up:
# ...

# %%
soup.title
# Out:
# <title>simple</title>

# %%
soup.head==soup.html.head
# Out:
# True

# %%
print(soup.toc)
# Out:
# None

# %%
div
# Out:
# [<div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation"><input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"><div class="toctitle" dir="ltr" lang="en"><h2 id="mw-toc-heading">Contents</h2><span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span></div>
#  <ul>
#  <li class="toclevel-1 tocsection-1"><a href="#Summary_of_classifications"><span class="tocnumber">1</span> <span class="toctext">Summary of classifications</span></a></li>
#  <li class="toclevel-1 tocsection-2"><a href="#Market_segments"><span class="tocnumber">2</span> <span class="toctext">Market segments</span></a>
#  <ul>
#  <li class="toclevel-2 tocsection-3"><a href="#Microcar_/_kei_car"><span class="tocnumber">2.1</span> <span class="toctext">Microcar / kei car</span></a></li>
# ...

# %%
div.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-c5826efdba7e> in <module>
# ----> 1 div.text
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1576     def __getattr__(self, key):
#    1577         raise AttributeError(
# -> 1578             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1579         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
div.prettify()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-897c492fad2d> in <module>
# ----> 1 div.prettify()
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1576     def __getattr__(self, key):
#    1577         raise AttributeError(
# -> 1578             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1579         )
#
# AttributeError: ResultSet object has no attribute 'prettify'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
div
# Out:
# [<div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation"><input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"><div class="toctitle" dir="ltr" lang="en"><h2 id="mw-toc-heading">Contents</h2><span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span></div>
#  <ul>
#  <li class="toclevel-1 tocsection-1"><a href="#Summary_of_classifications"><span class="tocnumber">1</span> <span class="toctext">Summary of classifications</span></a></li>
#  <li class="toclevel-1 tocsection-2"><a href="#Market_segments"><span class="tocnumber">2</span> <span class="toctext">Market segments</span></a>
#  <ul>
#  <li class="toclevel-2 tocsection-3"><a href="#Microcar_/_kei_car"><span class="tocnumber">2.1</span> <span class="toctext">Microcar / kei car</span></a></li>
# ...

# %%
div
# Out:
# [<div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation"><input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"><div class="toctitle" dir="ltr" lang="en"><h2 id="mw-toc-heading">Contents</h2><span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span></div>
#  <ul>
#  <li class="toclevel-1 tocsection-1"><a href="#Summary_of_classifications"><span class="tocnumber">1</span> <span class="toctext">Summary of classifications</span></a></li>
#  <li class="toclevel-1 tocsection-2"><a href="#Market_segments"><span class="tocnumber">2</span> <span class="toctext">Market segments</span></a>
#  <ul>
#  <li class="toclevel-2 tocsection-3"><a href="#Microcar_/_kei_car"><span class="tocnumber">2.1</span> <span class="toctext">Microcar / kei car</span></a></li>
# ...

# %%
div.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-c5826efdba7e> in <module>
# ----> 1 div.text
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1576     def __getattr__(self, key):
#    1577         raise AttributeError(
# -> 1578             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1579         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
soup=BeautifulSoup(s,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if (gt IE 9)|!(IE)]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <!-- www.phpied.com/conditional-comments-block-downloads/ -->
# <!-- Always force latest IE rendering engine
#          (even in intranet) & Chrome Frame
#          Remove this if you use the .htaccess -->
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <!--  Mobile Viewport Fix
#           j.mp/mobileviewport & davidbcalhoun.com/2010/viewport-metatag
#           device-width: Occupy full width of the screen in its current orientation
#           initial-scale = 1.0 retains dimensions instead of zooming out if page height > device height
#           user-scalable = yes allows the user to zoom in -->
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>simple</title>
# <!-- http://dev.w3.org/html5/markup/meta.name.html -->
# <meta content="simple" name="application-name"/>
# ...

# %%
dive=soup.find_all('div',class_='hatnote navigation-not-searchable')

# %%
dive
# Out:
# [<div class="hatnote navigation-not-searchable" role="note">This article is about the categorisation of cars according to vehicle regulations or market segments. For types of body styles (e.g. sedan, coupe, hatchback), see <a href="/wiki/Car_body_style" title="Car body style">Car body style</a>.</div>,
#  <div class="hatnote navigation-not-searchable" role="note">Main articles: <a href="/wiki/Microcar" title="Microcar">Microcar</a> and <a href="/wiki/Kei_car" title="Kei car">Kei car</a></div>,
#  <div class="hatnote navigation-not-searchable" role="note">Main article: <a href="/wiki/A-segment" title="A-segment">A-segment</a></div>,
#  <div class="hatnote navigation-not-searchable" role="note">Main articles: <a href="/wiki/B-segment" title="B-segment">B-segment</a>, <a href="/wiki/Supermini" title="Supermini">Supermini</a>, and <a href="/wiki/Subcompact_car" title="Subcompact car">Subcompact car</a></div>,
# ...

# %%
divt=soup.find('div',class_='thumb tright')

# %%
print(divt)
# Out:
# <div class="thumb tright"><div class="thumbinner" style="width:222px;"><a class="image" href="/wiki/File:2018_Aixam_Crossline_Premium_GT_CVT_600cc_Front.jpg"><img alt="" class="thumbimage" data-file-height="3270" data-file-width="4507" decoding="async" height="160" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/2018_Aixam_Crossline_Premium_GT_CVT_600cc_Front.jpg/220px-2018_Aixam_Crossline_Premium_GT_CVT_600cc_Front.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/2018_Aixam_Crossline_Premium_GT_CVT_600cc_Front.jpg/330px-2018_Aixam_Crossline_Premium_GT_CVT_600cc_Front.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/49/2018_Aixam_Crossline_Premium_GT_CVT_600cc_Front.jpg/440px-2018_Aixam_Crossline_Premium_GT_CVT_600cc_Front.jpg 2x" width="220"/></a> <div class="thumbcaption"><div class="magnify"><a class="internal" href="/wiki/File:2018_Aixam_Crossline_Premium_GT_CVT_600cc_Front.jpg" title="Enlarge"></a></div>2018 <a href="/wiki/Aixam" title="Aixam">
# ...

# %%
print(dive.prettify())
# Out:
# <div class="hatnote navigation-not-searchable" role="note">
#  This article is about the categorisation of cars according to vehicle regulations or market segments. For types of body styles (e.g. sedan, coupe, hatchback), see
#  <a href="/wiki/Car_body_style" title="Car body style">
#   Car body style
#  </a>
#  .
# </div>

# %%
print(divt.prettify())
# Out:
# <div class="thumb tright">
#  <div class="thumbinner" style="width:222px;">
#   <a class="image" href="/wiki/File:2018_Aixam_Crossline_Premium_GT_CVT_600cc_Front.jpg">
#    <img alt="" class="thumbimage" data-file-height="3270" data-file-width="4507" decoding="async" height="160" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/2018_Aixam_Crossline_Premium_GT_CVT_600cc_Front.jpg/220px-2018_Aixam_Crossline_Premium_GT_CVT_600cc_Front.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/2018_Aixam_Crossline_Premium_GT_CVT_600cc_Front.jpg/330px-2018_Aixam_Crossline_Premium_GT_CVT_600cc_Front.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/49/2018_Aixam_Crossline_Premium_GT_CVT_600cc_Front.jpg/440px-2018_Aixam_Crossline_Premium_GT_CVT_600cc_Front.jpg 2x" width="220"/>
#   </a>
#   <div class="thumbcaption">
#    <div class="magnify">
#     <a class="internal" href="/wiki/File:2018_Aixam_Crossline_Premium_GT_CVT_600cc_Front.jpg" title="Enlarge">
#     </a>
# ...

# %%
t=divt.find_all('a')[0]

# %%
print(t.prettify())
# Out:
# <a class="image" href="/wiki/File:2018_Aixam_Crossline_Premium_GT_CVT_600cc_Front.jpg">
#  <img alt="" class="thumbimage" data-file-height="3270" data-file-width="4507" decoding="async" height="160" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/2018_Aixam_Crossline_Premium_GT_CVT_600cc_Front.jpg/220px-2018_Aixam_Crossline_Premium_GT_CVT_600cc_Front.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/2018_Aixam_Crossline_Premium_GT_CVT_600cc_Front.jpg/330px-2018_Aixam_Crossline_Premium_GT_CVT_600cc_Front.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/49/2018_Aixam_Crossline_Premium_GT_CVT_600cc_Front.jpg/440px-2018_Aixam_Crossline_Premium_GT_CVT_600cc_Front.jpg 2x" width="220"/>
# </a>

# %%
list(i.text for i in soup.find_all('div',class_='hatnote navigation-not-searchable'))
# Out:
# ['This article is about the categorisation of cars according to vehicle regulations or market segments. For types of body styles (e.g. sedan, coupe, hatchback), see Car body style.',
#  'Main articles: Microcar and Kei car',
#  'Main article: A-segment',
#  'Main articles: B-segment, Supermini, and Subcompact car',
#  'Main articles: C-segment and Compact car',
#  'Main articles: D-segment and Mid-size car',
#  'Main articles: E-segment, Executive car, and Full-size car',
#  'Main article: Mini MPV',
#  'Main article: Compact MPV',
#  'Main article: Minivan',
#  'Main article: Luxury vehicle',
#  'Main article: Compact executive car',
#  'Main articles: Executive car, E-segment, and Full-size car',
#  'Main articles: F-segment and Luxury vehicle §\xa0Luxury saloon',
#  'Main article: Sports car',
#  'Main article: Sports sedan',
#  'Main article: Supercar',
#  'Main article: Off-road vehicle',
#  'Main article: Sport utility vehicle',
#  'Main article: Crossover (automobile)',
# ...

# %%
t=(soup.find_all('div',class_='hatnote navigation-not-searchable')[0])

# %%
t?

# %%
dive=soup.find_all('div',class_='hatnote navigation-not-searchable')
for i in range(0,len(dive)):
    print(dive[i].text)
    print()
# Out:
# This article is about the categorisation of cars according to vehicle regulations or market segments. For types of body styles (e.g. sedan, coupe, hatchback), see Car body style.
#
# Main articles: Microcar and Kei car
#
# Main article: A-segment
#
# Main articles: B-segment, Supermini, and Subcompact car
#
# Main articles: C-segment and Compact car
#
# Main articles: D-segment and Mid-size car
#
# Main articles: E-segment, Executive car, and Full-size car
#
# Main article: Mini MPV
#
# Main article: Compact MPV
#
# Main article: Minivan
#
# Main article: Luxury vehicle
#
# Main article: Compact executive car
#
# Main articles: Executive car, E-segment, and Full-size car
#
# Main articles: F-segment and Luxury vehicle § Luxury saloon
#
# Main article: Sports car
#
# Main article: Sports sedan
#
# Main article: Supercar
#
# Main article: Off-road vehicle
#
# Main article: Sport utility vehicle
#
# Main article: Crossover (automobile)
#
# Main article: Muscle car
#
# ...

# %%
len(dive)
# Out:
# 26

# %%
dive[25].text
# Out:
# 'Main article: Hot hatch'

# %%
print(dive.prettify())
# Out:
# <div class="hatnote navigation-not-searchable" role="note">
#  This article is about the categorisation of cars according to vehicle regulations or market segments. For types of body styles (e.g. sedan, coupe, hatchback), see
#  <a href="/wiki/Car_body_style" title="Car body style">
#   Car body style
#  </a>
#  .
# </div>

# %%
div
# Out:
# '<div class="hatnote navigation-not-searchable" role="note">\n This article is about the categorisation of cars according to vehicle regulations or market segments. For types of body styles (e.g. sedan, coupe, hatchback), see\n <a href="/wiki/Car_body_style" title="Car body style">\n  Car body style\n </a>\n .\n</div>\n'

# %%
 print(t.prettify())
# Out:
# <div class="hatnote navigation-not-searchable" role="note">
#  This article is about the categorisation of cars according to vehicle regulations or market segments. For types of body styles (e.g. sedan, coupe, hatchback), see
#  <a href="/wiki/Car_body_style" title="Car body style">
#   Car body style
#  </a>
#  .
# </div>

# %%
print(dive.prettify())
# Out:
# <span class="mw-editsection">
#  <span class="mw-editsection-bracket">
#   [
#  </span>
#  <a href="/w/index.php?title=Car_classification&amp;action=edit&amp;section=1" title="Edit section: Summary of classifications">
#   edit
#  </a>
#  <span class="mw-editsection-bracket">
#   ]
#  </span>
# </span>

# %%
list(dive.stripped_strings)
# Out:
# ['[', 'edit', ']']

# %%
div
# Out:
# [<span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Car_classification&amp;action=edit&amp;section=1" title="Edit section: Summary of classifications">edit</a><span class="mw-editsection-bracket">]</span></span>,
#  <span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Car_classification&amp;action=edit&amp;section=2" title="Edit section: Market segments">edit</a><span class="mw-editsection-bracket">]</span></span>,
#  <span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Car_classification&amp;action=edit&amp;section=3" title="Edit section: Microcar / kei car">edit</a><span class="mw-editsection-bracket">]</span></span>,
# ...

# %%
div.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-134-c5826efdba7e> in <module>
# ----> 1 div.text
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1576     def __getattr__(self, key):
#    1577         raise AttributeError(
# -> 1578             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1579         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
div
# Out:
# []

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if (gt IE 9)|!(IE)]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <!-- www.phpied.com/conditional-comments-block-downloads/ -->
# <!-- Always force latest IE rendering engine
#          (even in intranet) & Chrome Frame
#          Remove this if you use the .htaccess -->
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <!--  Mobile Viewport Fix
#           j.mp/mobileviewport & davidbcalhoun.com/2010/viewport-metatag
#           device-width: Occupy full width of the screen in its current orientation
#           initial-scale = 1.0 retains dimensions instead of zooming out if page height > device height
#           user-scalable = yes allows the user to zoom in -->
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>simple</title>
# <!-- http://dev.w3.org/html5/markup/meta.name.html -->
# <meta content="simple" name="application-name"/>
# ...

# %%
div
# Out:
# [<div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation"><input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"><div class="toctitle" dir="ltr" lang="en"><h2 id="mw-toc-heading">Contents</h2><span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span></div>
#  <ul>
#  <li class="toclevel-1 tocsection-1"><a href="#Summary_of_classifications"><span class="tocnumber">1</span> <span class="toctext">Summary of classifications</span></a></li>
#  <li class="toclevel-1 tocsection-2"><a href="#Market_segments"><span class="tocnumber">2</span> <span class="toctext">Market segments</span></a>
#  <ul>
#  <li class="toclevel-2 tocsection-3"><a href="#Microcar_/_kei_car"><span class="tocnumber">2.1</span> <span class="toctext">Microcar / kei car</span></a></li>
# ...

# %%
print(div[0])
# Out:
# <div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation"><input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"><div class="toctitle" dir="ltr" lang="en"><h2 id="mw-toc-heading">Contents</h2><span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span></div>
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#Summary_of_classifications"><span class="tocnumber">1</span> <span class="toctext">Summary of classifications</span></a></li>
# <li class="toclevel-1 tocsection-2"><a href="#Market_segments"><span class="tocnumber">2</span> <span class="toctext">Market segments</span></a>
# <ul>
# <li class="toclevel-2 tocsection-3"><a href="#Microcar_/_kei_car"><span class="tocnumber">2.1</span> <span class="toctext">Microcar / kei car</span></a></li>
# ...
